# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("house.csv")

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df.shape
# Out:
# (545, 13)

# %%
df.dtypes
# Out:
# price                int64
# area                 int64
# bedrooms             int64
# bathrooms            int64
# stories              int64
# mainroad            object
# guestroom           object
# basement            object
# hotwaterheating     object
# airconditioning     object
# parking              int64
# prefarea            object
# furnishingstatus    object
# dtype: object

# %%
df.head(10)
# Out:
#       price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000   7420         4          2        3      yes        no       no
# 1  12250000   8960         4          4        4      yes        no       no
# 2  12250000   9960         3          2        2      yes        no      yes
# 3  12215000   7500         4          2        2      yes        no      yes
# 4  11410000   7420         4          1        2      yes       yes      yes
# 5  10850000   7500         3          3        1      yes        no      yes
# 6  10150000   8580         4          3        4      yes        no       no
# 7  10150000  16200         5          3        2      yes        no       no
# 8   9870000   8100         4          1        2      yes       yes      yes
# 9   9800000   5750         3          2        4      yes       yes       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %%
df.tail(10)
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 535  2100000  3360         2          1        1      yes        no       no
# 536  1960000  3420         5          1        2       no        no       no
# 537  1890000  1700         3          1        2      yes        no       no
# 538  1890000  3649         2          1        1      yes        no       no
# 539  1855000  2990         2          1        1       no        no       no
# 540  1820000  3000         2          1        1      yes        no      yes
# 541  1767150  2400         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 544  1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
df.isna()
# Out:
#      price   area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    False  False     False      False    False     False      False
# 1    False  False     False      False    False     False      False
# 2    False  False     False      False    False     False      False
# 3    False  False     False      False    False     False      False
# 4    False  False     False      False    False     False      False
# ..     ...    ...       ...        ...      ...       ...        ...
# 540  False  False     False      False    False     False      False
# 541  False  False     False      False    False     False      False
# 542  False  False     False      False    False     False      False
# 543  False  False     False      False    False     False      False
# 544  False  False     False      False    False     False      False
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0       False            False            False    False     False
# ...

# %%
df.isna().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
df.count()
# Out:
# price               545
# area                545
# bedrooms            545
# bathrooms           545
# stories             545
# mainroad            545
# guestroom           545
# basement            545
# hotwaterheating     545
# airconditioning     545
# parking             545
# prefarea            545
# furnishingstatus    545
# dtype: int64

# %%
df[df==0].count()
# Out:
# price                 0
# area                  0
# bedrooms              0
# bathrooms             0
# stories               0
# mainroad              0
# guestroom             0
# basement              0
# hotwaterheating       0
# airconditioning       0
# parking             299
# prefarea              0
# furnishingstatus      0
# dtype: int64

# %%
df[["price","area","bedrooms","bathrooms","stories","parking"]].mean()
# Out:
# price        4.766729e+06
# area         5.150541e+03
# bedrooms     2.965138e+00
# bathrooms    1.286239e+00
# stories      1.805505e+00
# parking      6.935780e-01
# dtype: float64

# %%
df.mean(numeric_only = True)
# Out:
# price        4.766729e+06
# area         5.150541e+03
# bedrooms     2.965138e+00
# bathrooms    1.286239e+00
# stories      1.805505e+00
# parking      6.935780e-01
# dtype: float64

# %%
df1 = df.copy()

# %%
df1
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df2 = df[["price","area","bedrooms","stories","guestroom","airconditioning","parking","furnishingstatus"]]

# %%
df2
# Out:
#         price  area  bedrooms  stories guestroom airconditioning  parking  \
# 0    13300000  7420         4        3        no             yes        2
# 1    12250000  8960         4        4        no             yes        3
# 2    12250000  9960         3        2        no              no        2
# 3    12215000  7500         4        2        no             yes        3
# 4    11410000  7420         4        2       yes             yes        2
# ..        ...   ...       ...      ...       ...             ...      ...
# 540   1820000  3000         2        1        no              no        2
# 541   1767150  2400         3        1        no              no        0
# 542   1750000  3620         2        1        no              no        0
# 543   1750000  2910         3        1        no              no        0
# 544   1750000  3850         3        2        no              no        0
#
#     furnishingstatus
# 0          furnished
# 1          furnished
# ...

# %%
df4 = df.iloc[0:100, [0,1,2,4,6,9,10,12]]

# %%
df4
# Out:
#        price  area  bedrooms  stories guestroom airconditioning  parking  \
# 0   13300000  7420         4        3        no             yes        2
# 1   12250000  8960         4        4        no             yes        3
# 2   12250000  9960         3        2        no              no        2
# 3   12215000  7500         4        2        no             yes        3
# 4   11410000  7420         4        2       yes             yes        2
# ..       ...   ...       ...      ...       ...             ...      ...
# 95   6300000  4100         3        3        no             yes        2
# 96   6300000  9000         3        1        no              no        1
# 97   6300000  6400         3        1       yes             yes        1
# 98   6293000  6600         3        3        no             yes        0
# 99   6265000  6000         4        3       yes              no        0
#
#    furnishingstatus
# 0         furnished
# 1         furnished
# 2    semi-furnished
# ...

# %%
df3 = df[["price","area","bedrooms","stories","parking"]]

# %%
df3
# Out:
#         price  area  bedrooms  stories  parking
# 0    13300000  7420         4        3        2
# 1    12250000  8960         4        4        3
# 2    12250000  9960         3        2        2
# 3    12215000  7500         4        2        3
# 4    11410000  7420         4        2        2
# ..        ...   ...       ...      ...      ...
# 540   1820000  3000         2        1        2
# 541   1767150  2400         3        1        0
# 542   1750000  3620         2        1        0
# 543   1750000  2910         3        1        0
# 544   1750000  3850         3        2        0
#
# [545 rows x 5 columns]

# %%
df1[df1["furnishingstatus"] == "furnished"]
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# 8     9870000  8100         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 509   2590000  3600         2          2        2      yes        no      yes
# 512   2520000  3000         2          1        2      yes        no       no
# 522   2380000  2475         3          1        2      yes        no       no
# 523   2380000  2787         4          2        2      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
#
# ...

# %%
x=df[["area","bedrooms","bathrooms","stories","mainroad","guestroom","basement","hotwaterheating","airconditioning","prefarea","furnishingstatus","parking"]]

# %%
x.columns
# Out:
# Index(['area', 'bedrooms', 'bathrooms', 'stories', 'mainroad', 'guestroom',
#        'basement', 'hotwaterheating', 'airconditioning', 'prefarea',
#        'furnishingstatus', 'parking'],
#       dtype='object')

# %%
y=df[["price"]]

# %%
y.columns
# Out:
# Index(['price'], dtype='object')

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x,y,train_size=0.75)

# %%
print(x_train.shape)
print(x_train)
# Out:
# (408, 12)
#      area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 362  4050         2          1        1      yes        no       no
# 433  3480         4          1        2       no        no       no
# 226  5170         3          1        4      yes        no       no
# 107  6420         3          1        3      yes        no      yes
# 544  3850         3          1        2      yes        no       no
# ..    ...       ...        ...      ...      ...       ...      ...
# 350  3420         2          1        2      yes        no       no
# 500  2800         3          1        1      yes        no       no
# 286  2787         3          1        1      yes        no      yes
# 187  6100         3          1        1      yes        no      yes
# 145  5000         3          1        4      yes        no       no
#
#     hotwaterheating airconditioning prefarea furnishingstatus  parking
# ...

# %%
print(x_test.shape)
print(x_test)
# Out:
# (137, 12)
#      area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 477  4960         2          1        1      yes        no       no
# 184  3000         3          2        2      yes       yes      yes
# 461  4960         2          1        1      yes        no      yes
# 149  6600         4          2        1      yes        no      yes
# 41   6360         3          2        4      yes        no       no
# ..    ...       ...        ...      ...      ...       ...      ...
# 464  4500         2          1        2      yes        no       no
# 494  6800         2          1        1      yes        no       no
# 528  3970         1          1        1       no        no       no
# 98   6600         3          2        3      yes        no       no
# 275  4032         2          1        1      yes        no      yes
#
#     hotwaterheating airconditioning prefarea furnishingstatus  parking
# ...

# %%
print(y_train.shape)
print(y_train)
# Out:
# (408, 1)
#        price
# 362  3710000
# 433  3290000
# 226  4690000
# 107  6125000
# 544  1750000
# ..       ...
# 350  3780000
# 500  2660000
# 286  4235000
# 187  5110000
# 145  5600000
#
# [408 rows x 1 columns]

# %%
print(y_test.shape)
print(y_test)
# Out:
# (137, 1)
#        price
# 477  2940000
# 184  5110000
# 461  3080000
# 149  5600000
# 41   7840000
# ..       ...
# 464  3080000
# 494  2730000
# 528  2275000
# 98   6293000
# 275  4319000
#
# [137 rows x 1 columns]

# %%
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
import seaborn as sns

# %%
sns.pairplot(df, hue="furnishingstatus")

# %%
x = df.iloc[ :, 1: ]
y = df.iloc[ :,  :1]
x_train, x_test, y_train, y_test = train_test_split(x,y,train_size=0.75, random_state = 0)

# %%
print(x_train.shape)
print(x_train)
# Out:
# (408, 12)
#       area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 498   2000         2          1        2      yes        no       no
# 531   5300         3          1        1       no        no       no
# 532   3000         2          1        1       no        no       no
# 278   3400         3          1        2      yes        no      yes
# 101   5500         3          1        3      yes        no       no
# ..     ...       ...        ...      ...      ...       ...      ...
# 70    4000         3          2        2      yes        no      yes
# 277  10360         2          1        1      yes        no       no
# 9     5750         3          2        4      yes       yes       no
# 359   3600         3          1        1      yes        no       no
# 192   6600         3          1        1      yes       yes      yes
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %%
print(x_test.shape)
x_test
# Out:
# (137, 12)
#       area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 239   4000         3          1        2      yes        no       no
# 113   9620         3          1        1      yes        no      yes
# 325   3460         4          1        2      yes        no       no
# 66   13200         2          1        1      yes        no      yes
# 479   3660         4          1        2       no        no       no
# ..     ...       ...        ...      ...      ...       ...      ...
# 319   3000         4          1        3      yes        no      yes
# 525   3640         2          1        1      yes        no       no
# 245   5360         3          1        2      yes        no       no
# 7    16200         5          3        2      yes        no       no
# 375   5960         3          1        2      yes       yes      yes
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %%
print(y_train.shape)
print(y_train)
# Out:
# (408, 1)
#        price
# 498  2660000
# 531  2233000
# 532  2135000
# 278  4277000
# 101  6230000
# ..       ...
# 70   6790000
# 277  4305000
# 9    9800000
# 359  3710000
# 192  5040000
#
# [408 rows x 1 columns]

# %%
print(y_test.shape)
print(y_test)
# Out:
# (137, 1)
#         price
# 239   4585000
# 113   6083000
# 325   4007500
# 66    6930000
# 479   2940000
# ..        ...
# 319   4060000
# 525   2345000
# 245   4550000
# 7    10150000
# 375   3640000
#
# [137 rows x 1 columns]
