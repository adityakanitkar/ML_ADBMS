# %%
import pandas as pd

# %%
data = pd.read_csv("/home/student/Alpha/Dataset.csv");

# %%
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
#shape of the dataset
data.shape
# Out:
# (545, 13)

# %%
#1st 10 records display
data.head(10)
# Out:
#       price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000   7420         4          2        3      yes        no       no
# 1  12250000   8960         4          4        4      yes        no       no
# 2  12250000   9960         3          2        2      yes        no      yes
# 3  12215000   7500         4          2        2      yes        no      yes
# 4  11410000   7420         4          1        2      yes       yes      yes
# 5  10850000   7500         3          3        1      yes        no      yes
# 6  10150000   8580         4          3        4      yes        no       no
# 7  10150000  16200         5          3        2      yes        no       no
# 8   9870000   8100         4          1        2      yes       yes      yes
# 9   9800000   5750         3          2        4      yes       yes       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %%
#last 10 records display
data.tail(10)
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 535  2100000  3360         2          1        1      yes        no       no
# 536  1960000  3420         5          1        2       no        no       no
# 537  1890000  1700         3          1        2      yes        no       no
# 538  1890000  3649         2          1        1      yes        no       no
# 539  1855000  2990         2          1        1       no        no       no
# 540  1820000  3000         2          1        1      yes        no      yes
# 541  1767150  2400         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 544  1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %%
#check missing values
data.isnull()
# Out:
#      price   area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    False  False     False      False    False     False      False
# 1    False  False     False      False    False     False      False
# 2    False  False     False      False    False     False      False
# 3    False  False     False      False    False     False      False
# 4    False  False     False      False    False     False      False
# ..     ...    ...       ...        ...      ...       ...        ...
# 540  False  False     False      False    False     False      False
# 541  False  False     False      False    False     False      False
# 542  False  False     False      False    False     False      False
# 543  False  False     False      False    False     False      False
# 544  False  False     False      False    False     False      False
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0       False            False            False    False     False
# ...

# %%
#count total missing values
data.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
data.count()
# Out:
# price               545
# area                545
# bedrooms            545
# bathrooms           545
# stories             545
# mainroad            545
# guestroom           545
# basement            545
# hotwaterheating     545
# airconditioning     545
# parking             545
# prefarea            545
# furnishingstatus    545
# dtype: int64

# %%
#display missing value in dataset
data.isna()
# Out:
#      price   area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    False  False     False      False    False     False      False
# 1    False  False     False      False    False     False      False
# 2    False  False     False      False    False     False      False
# 3    False  False     False      False    False     False      False
# 4    False  False     False      False    False     False      False
# ..     ...    ...       ...        ...      ...       ...        ...
# 540  False  False     False      False    False     False      False
# 541  False  False     False      False    False     False      False
# 542  False  False     False      False    False     False      False
# 543  False  False     False      False    False     False      False
# 544  False  False     False      False    False     False      False
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0       False            False            False    False     False
# ...

# %%
#datatype of each column
data.dtypes
# Out:
# price                int64
# area                 int64
# bedrooms             int64
# bathrooms            int64
# stories              int64
# mainroad            object
# guestroom           object
# basement            object
# hotwaterheating     object
# airconditioning     object
# parking              int64
# prefarea            object
# furnishingstatus    object
# dtype: object

# %%
#total no of zeroes in each column
data == 0
# Out:
#      price   area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    False  False     False      False    False     False      False
# 1    False  False     False      False    False     False      False
# 2    False  False     False      False    False     False      False
# 3    False  False     False      False    False     False      False
# 4    False  False     False      False    False     False      False
# ..     ...    ...       ...        ...      ...       ...        ...
# 540  False  False     False      False    False     False      False
# 541  False  False     False      False    False     False      False
# 542  False  False     False      False    False     False      False
# 543  False  False     False      False    False     False      False
# 544  False  False     False      False    False     False      False
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0       False            False            False    False     False
# ...

# %%
#count total no. of zeroes into dataset
data[data==0].count()
# Out:
# price                 0
# area                  0
# bedrooms              0
# bathrooms             0
# stories               0
# mainroad              0
# guestroom             0
# basement              0
# hotwaterheating       0
# airconditioning       0
# parking             299
# prefarea              0
# furnishingstatus      0
# dtype: int64

# %%
#mean of each column in a dataset
data['price'].mean()
# Out:
# 4766729.247706422

# %%
#mean of column which containing numbers
data[['price','area','bedrooms','bathrooms','stories','parking']].mean()
# Out:
# price        4.766729e+06
# area         5.150541e+03
# bedrooms     2.965138e+00
# bathrooms    1.286239e+00
# stories      1.805505e+00
# parking      6.935780e-01
# dtype: float64

# %%
#dividing dataset into subset
traning = data[["price","area","bedrooms","stories","guestroom","airconditioning"]]

# %%
traning
# Out:
#         price  area  bedrooms  stories guestroom airconditioning
# 0    13300000  7420         4        3        no             yes
# 1    12250000  8960         4        4        no             yes
# 2    12250000  9960         3        2        no              no
# 3    12215000  7500         4        2        no             yes
# 4    11410000  7420         4        2       yes             yes
# ..        ...   ...       ...      ...       ...             ...
# 540   1820000  3000         2        1        no              no
# 541   1767150  2400         3        1        no              no
# 542   1750000  3620         2        1        no              no
# 543   1750000  2910         3        1        no              no
# 544   1750000  3850         3        2        no              no
#
# [545 rows x 6 columns]

# %%
#dataset 1
traning1 = data[["price","area","bedrooms","stories","guestroom","airconditioning","furnishingstatus"]]

# %%
traning1
# Out:
#         price  area  bedrooms  stories guestroom airconditioning  \
# 0    13300000  7420         4        3        no             yes
# 1    12250000  8960         4        4        no             yes
# 2    12250000  9960         3        2        no              no
# 3    12215000  7500         4        2        no             yes
# 4    11410000  7420         4        2       yes             yes
# ..        ...   ...       ...      ...       ...             ...
# 540   1820000  3000         2        1        no              no
# 541   1767150  2400         3        1        no              no
# 542   1750000  3620         2        1        no              no
# 543   1750000  2910         3        1        no              no
# 544   1750000  3850         3        2        no              no
#
#     furnishingstatus
# 0          furnished
# 1          furnished
# 2     semi-furnished
# 3          furnished
# 4          furnished
# ..               ...
# 540      unfurnished
# ...

# %%
#dataset 2
testing1 = data[["parking","furnishingstatus"]]

# %%
testing1
# Out:
#      parking furnishingstatus
# 0          2        furnished
# 1          3        furnished
# 2          2   semi-furnished
# 3          3        furnished
# 4          2        furnished
# ..       ...              ...
# 540        2      unfurnished
# 541        0   semi-furnished
# 542        0      unfurnished
# 543        0        furnished
# 544        0      unfurnished
#
# [545 rows x 2 columns]

# %%
#1st 100 rows of training set
traning2 = data[["price","area","bedrooms","stories","guestroom","airconditioning","furnishingstatus"]].head(100)

# %%
traning2
# Out:
#        price  area  bedrooms  stories guestroom airconditioning  \
# 0   13300000  7420         4        3        no             yes
# 1   12250000  8960         4        4        no             yes
# 2   12250000  9960         3        2        no              no
# 3   12215000  7500         4        2        no             yes
# 4   11410000  7420         4        2       yes             yes
# ..       ...   ...       ...      ...       ...             ...
# 95   6300000  4100         3        3        no             yes
# 96   6300000  9000         3        1        no              no
# 97   6300000  6400         3        1       yes             yes
# 98   6293000  6600         3        3        no             yes
# 99   6265000  6000         4        3       yes              no
#
#    furnishingstatus
# 0         furnished
# 1         furnished
# 2    semi-furnished
# 3         furnished
# 4         furnished
# ..              ...
# 95   semi-furnished
# 96        furnished
# ...

# %%
#1st 100 rows of testing dataset
test = data[["parking","furnishingstatus"]].head(100)

# %%
test
# Out:
#     parking furnishingstatus
# 0         2        furnished
# 1         3        furnished
# 2         2   semi-furnished
# 3         3        furnished
# 4         2        furnished
# ..      ...              ...
# 95        2   semi-furnished
# 96        1        furnished
# 97        1   semi-furnished
# 98        0      unfurnished
# 99        0      unfurnished
#
# [100 rows x 2 columns]

# %%
#subset of all 5 columns and all rows
data1 = data[["price","area","parking","furnishingstatus","guestroom"]]

# %%
data1
# Out:
#         price  area  parking furnishingstatus guestroom
# 0    13300000  7420        2        furnished        no
# 1    12250000  8960        3        furnished        no
# 2    12250000  9960        2   semi-furnished        no
# 3    12215000  7500        3        furnished        no
# 4    11410000  7420        2        furnished       yes
# ..        ...   ...      ...              ...       ...
# 540   1820000  3000        2      unfurnished        no
# 541   1767150  2400        0   semi-furnished        no
# 542   1750000  3620        0      unfurnished        no
# 543   1750000  2910        0        furnished        no
# 544   1750000  3850        0      unfurnished        no
#
# [545 rows x 5 columns]

# %%
#subset of all columns n rows where furnishingstatus is furnished
data2 = data[data["furnishingstatus"]=="furnished"]

# %%
data2
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# 8     9870000  8100         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 509   2590000  3600         2          2        2      yes        no      yes
# 512   2520000  3000         2          1        2      yes        no       no
# 522   2380000  2475         3          1        2      yes        no       no
# 523   2380000  2787         4          2        2      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
#
# ...

# %%
import numpy as np

# %%
from sklearn.model_selection import train_test_split

# %%
#train test split 75% training and 25% testing
train, test = train_test_split(data,random_state=0,test_size= 0.25)

# %%
train.shape
# Out:
# (408, 13)

# %%
test.shape
# Out:
# (137, 13)

# %%
d =train

# %%
d
# Out:
#        price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 498  2660000   2000         2          1        2      yes        no       no
# 531  2233000   5300         3          1        1       no        no       no
# 532  2135000   3000         2          1        1       no        no       no
# 278  4277000   3400         3          1        2      yes        no      yes
# 101  6230000   5500         3          1        3      yes        no       no
# ..       ...    ...       ...        ...      ...      ...       ...      ...
# 70   6790000   4000         3          2        2      yes        no      yes
# 277  4305000  10360         2          1        1      yes        no       no
# 9    9800000   5750         3          2        4      yes       yes       no
# 359  3710000   3600         3          1        1      yes        no       no
# 192  5040000   6600         3          1        1      yes       yes      yes
#
# ...

# %%
s = test

# %%
s
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 239   4585000   4000         3          1        2      yes        no
# 113   6083000   9620         3          1        1      yes        no
# 325   4007500   3460         4          1        2      yes        no
# 66    6930000  13200         2          1        1      yes        no
# 479   2940000   3660         4          1        2       no        no
# ..        ...    ...       ...        ...      ...      ...       ...
# 319   4060000   3000         4          1        3      yes        no
# 525   2345000   3640         2          1        1      yes        no
# 245   4550000   5360         3          1        2      yes        no
# 7    10150000  16200         5          3        2      yes        no
# 375   3640000   5960         3          1        2      yes       yes
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
#train test split 80, 20
train, test = train_test_split(data,random_state = 0,train_size= 0.80)

# %%
train.shape
# Out:
# (436, 13)

# %%
test.shape
# Out:
# (109, 13)

# %%
d1 = train

# %%
d1
# Out:
#        price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 542  1750000   3620         2          1        1      yes        no       no
# 496  2695000   4000         2          1        1      yes        no       no
# 484  2870000   3040         2          1        1       no        no       no
# 507  2590000   3600         2          1        1      yes        no       no
# 252  4515000   9860         3          1        1      yes        no       no
# ..       ...    ...       ...        ...      ...      ...       ...      ...
# 70   6790000   4000         3          2        2      yes        no      yes
# 277  4305000  10360         2          1        1      yes        no       no
# 9    9800000   5750         3          2        4      yes       yes       no
# 359  3710000   3600         3          1        1      yes        no       no
# 192  5040000   6600         3          1        1      yes       yes      yes
#
# ...

# %%
s1 = test

# %%
s1
# Out:
#        price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 239  4585000   4000         3          1        2      yes        no       no
# 113  6083000   9620         3          1        1      yes        no      yes
# 325  4007500   3460         4          1        2      yes        no       no
# 66   6930000  13200         2          1        1      yes        no      yes
# 479  2940000   3660         4          1        2       no        no       no
# ..       ...    ...       ...        ...      ...      ...       ...      ...
# 76   6650000   6420         3          2        3      yes        no       no
# 132  5810000   5200         3          1        3      yes        no       no
# 311  4123000   6060         2          1        1      yes        no      yes
# 464  3080000   4500         2          1        2      yes        no       no
# 155  5530000   6100         3          2        1      yes        no      yes
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
#pairplot
sns.pairplot(data)

# %%
sns.pairplot(data,hue = "price")

# %%
sns.pairplot(data,hue = "area")

# %%
sns.pairplot(data, hue = "furnishingstatus")

# %%
sns.pairplot(data, hue = "parking", kind = "hist")

# %%
sns.pairplot(data, hue = "furnishingstatus",kind = "hist" )

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# %%
X = data[["area","bedrooms","bathrooms","stories","mainroad","guestroom","basement","hotwaterheating","airconditioning","parking","prefarea","furnishingstatus"]]

# %%
Y = data[["price"]]

# %%
X
# Out:
#      area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    7420         4          2        3      yes        no       no
# 1    8960         4          4        4      yes        no       no
# 2    9960         3          2        2      yes        no      yes
# 3    7500         4          2        2      yes        no      yes
# 4    7420         4          1        2      yes       yes      yes
# ..    ...       ...        ...      ...      ...       ...      ...
# 540  3000         2          1        1      yes        no      yes
# 541  2400         3          1        1       no        no       no
# 542  3620         2          1        1      yes        no       no
# 543  2910         3          1        1       no        no       no
# 544  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0                no             yes        2      yes        furnished
# ...

# %%
Y
# Out:
#         price
# 0    13300000
# 1    12250000
# 2    12250000
# 3    12215000
# 4    11410000
# ..        ...
# 540   1820000
# 541   1767150
# 542   1750000
# 543   1750000
# 544   1750000
#
# [545 rows x 1 columns]

# %%
#train test split 75 and 25
X_train, X_test, y_train,y_test = train_test_split(X,Y,random_state=0, test_size=0.25)

# %%
X_train
# Out:
#       area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 498   2000         2          1        2      yes        no       no
# 531   5300         3          1        1       no        no       no
# 532   3000         2          1        1       no        no       no
# 278   3400         3          1        2      yes        no      yes
# 101   5500         3          1        3      yes        no       no
# ..     ...       ...        ...      ...      ...       ...      ...
# 70    4000         3          2        2      yes        no      yes
# 277  10360         2          1        1      yes        no       no
# 9     5750         3          2        4      yes       yes       no
# 359   3600         3          1        1      yes        no       no
# 192   6600         3          1        1      yes       yes      yes
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %%
X_test
# Out:
#       area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 239   4000         3          1        2      yes        no       no
# 113   9620         3          1        1      yes        no      yes
# 325   3460         4          1        2      yes        no       no
# 66   13200         2          1        1      yes        no      yes
# 479   3660         4          1        2       no        no       no
# ..     ...       ...        ...      ...      ...       ...      ...
# 319   3000         4          1        3      yes        no      yes
# 525   3640         2          1        1      yes        no       no
# 245   5360         3          1        2      yes        no       no
# 7    16200         5          3        2      yes        no       no
# 375   5960         3          1        2      yes       yes      yes
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %%
y_train
# Out:
#        price
# 498  2660000
# 531  2233000
# 532  2135000
# 278  4277000
# 101  6230000
# ..       ...
# 70   6790000
# 277  4305000
# 9    9800000
# 359  3710000
# 192  5040000
#
# [408 rows x 1 columns]

# %%
y_test
# Out:
#         price
# 239   4585000
# 113   6083000
# 325   4007500
# 66    6930000
# 479   2940000
# ..        ...
# 319   4060000
# 525   2345000
# 245   4550000
# 7    10150000
# 375   3640000
#
# [137 rows x 1 columns]

# %%
X_train.shape
# Out:
# (408, 12)

# %%
y_train.shape
# Out:
# (408, 1)
