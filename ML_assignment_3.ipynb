# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("admission_predict.csv")

# %%
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        324          107                  4  4.0  4.5  8.87
# 2             3        316          104                  3  3.0  3.5  8.00
# 3             4        322          110                  3  3.5  2.5  8.67
# 4             5        314          103                  2  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 395         396        324          110                  3  3.5  3.5  9.04
# 396         397        325          107                  3  3.0  3.5  9.11
# 397         398        330          116                  4  5.0  4.5  9.45
# 398         399        312          103                  3  3.5  4.0  8.78
# 399         400        333          117                  4  5.0  4.0  9.66
#
#      Research  Chance of Admit
# 0           1             0.92
# ...

# %%
df.shape
# Out:
# (400, 9)

# %%
df.dtypes
# Out:
# Serial No.             int64
# GRE Score              int64
# TOEFL Score            int64
# University Rating      int64
# SOP                  float64
# LOR                  float64
# CGPA                 float64
# Research               int64
# Chance of Admit      float64
# dtype: object

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        324          107                  4  4.0  4.5  8.87
# 2           3        316          104                  3  3.0  3.5  8.00
# 3           4        322          110                  3  3.5  2.5  8.67
# 4           5        314          103                  2  2.0  3.0  8.21
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.76
# 2         1             0.72
# 3         1             0.80
# 4         0             0.65

# %%
df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#               LOR        CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000       400.000000
# mean     3.452500    8.598925    0.547500         0.724350
# std      0.898478    0.596317    0.498362         0.142609
# min      1.000000    6.800000    0.000000         0.340000
# ...

# %%
df.mean(numeric_only = True)
# Out:
# Serial No.           200.500000
# GRE Score            316.807500
# TOEFL Score          107.410000
# University Rating      3.087500
# SOP                    3.400000
# LOR                    3.452500
# CGPA                   8.598925
# Research               0.547500
# Chance of Admit        0.724350
# dtype: float64

# %%
df.isna()
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating    SOP    LOR  \
# 0         False      False        False              False  False  False
# 1         False      False        False              False  False  False
# 2         False      False        False              False  False  False
# 3         False      False        False              False  False  False
# 4         False      False        False              False  False  False
# ..          ...        ...          ...                ...    ...    ...
# 395       False      False        False              False  False  False
# 396       False      False        False              False  False  False
# 397       False      False        False              False  False  False
# 398       False      False        False              False  False  False
# 399       False      False        False              False  False  False
#
#       CGPA  Research  Chance of Admit
# 0    False     False            False
# ...

# %%
df.isna().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
from sklearn.preprocessing import Binarizer
bi=Binarizer(threshold=0.87)
df["Chance of Admit"]=bi.fit_transform(df[["Chance of Admit"]])

# %%
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        324          107                  4  4.0  4.5  8.87
# 2             3        316          104                  3  3.0  3.5  8.00
# 3             4        322          110                  3  3.5  2.5  8.67
# 4             5        314          103                  2  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 395         396        324          110                  3  3.5  3.5  9.04
# 396         397        325          107                  3  3.0  3.5  9.11
# 397         398        330          116                  4  5.0  4.5  9.45
# 398         399        312          103                  3  3.5  4.0  8.78
# 399         400        333          117                  4  5.0  4.0  9.66
#
#      Research  Chance of Admit
# 0           1              1.0
# ...

# %%
df.rename(columns={"Chance of Admit":"Admitted"},inplace=True)
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        324          107                  4  4.0  4.5  8.87
# 2             3        316          104                  3  3.0  3.5  8.00
# 3             4        322          110                  3  3.5  2.5  8.67
# 4             5        314          103                  2  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 395         396        324          110                  3  3.5  3.5  9.04
# 396         397        325          107                  3  3.0  3.5  9.11
# 397         398        330          116                  4  5.0  4.5  9.45
# 398         399        312          103                  3  3.5  4.0  8.78
# 399         400        333          117                  4  5.0  4.0  9.66
#
#      Research  Admitted
# 0           1       1.0
# ...

# %%
df.drop("Serial No.", axis=1, inplace=True)

# %%
sns.scatterplot(data=df, x=df["GRE Score"], y=df["Admitted"], hue="TOEFL Score")
# Out:
# <Axes: xlabel='GRE Score', ylabel='Admitted'>

# %%
sns.scatterplot(data=df,x=df["TOEFL Score"], y=df["Admitted"] ,hue="TOEFL Score")
# Out:
# <Axes: xlabel='TOEFL Score', ylabel='Admitted'>

# %%
sns.scatterplot(data=df, x=df["University Rating"], y=df["Admitted"], hue="University Rating")
# Out:
# <Axes: xlabel='University Rating', ylabel='Admitted'>

# %%
sns.scatterplot(data=df,x="SOP",y="Admitted",hue="SOP")
# Out:
# <Axes: xlabel='SOP', ylabel='Admitted'>

# %%
sns.scatterplot(data=df,x="CGPA",y="Admitted",hue="CGPA")
# Out:
# <Axes: xlabel='CGPA', ylabel='Admitted'>

# %%
sns.scatterplot(data=df,x="LOR",y="Admitted",hue="CGPA")
# Out:
# <Axes: xlabel='LOR', ylabel='Admitted'>

# %%
sns.scatterplot(data=df,x="Research",y="Admitted",hue="Research")
# Out:
# <Axes: xlabel='Research', ylabel='Admitted'>

# %%
sns.boxplot(df["GRE Score"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["TOEFL Score"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["University Rating"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["SOP"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["LOR"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["CGPA"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["Research"])
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR', 'CGPA',
#        'Research', 'Admitted'],
#       dtype='object')

# %%
df["Admitted"].value_counts()
# Out:
# Admitted
# 0.0    330
# 1.0     70
# Name: count, dtype: int64

# %%
sns.countplot(x=df["Admitted"],hue=df["Admitted"])
# Out:
# <Axes: xlabel='Admitted', ylabel='count'>

# %%
count=df["Research"].value_counts()
labels=['0','1']
plt.figure(figsize=(10,10))
plt.pie(count,labels=labels, startangle=90, autopct ='%1.1f%%')
plt.show()

# %%
sns.displot(df["GRE Score"] , kde=True, bins=15)
# Out:
# C:\Users\91952\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.barplot(data=df, x="SOP",y="Admitted")
plt.ylabel("Admitted")
plt.xlabel("GRE Score")
plt.show()

# %%
x=df.drop("Admitted",axis=1)
y=df["Admitted"]

# %%
import sklearn.model_selection
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.75)

# %%
print(x_train.shape)
print(x_train)
# Out:
# (300, 7)
#      GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research
# 9          323          108                  3  3.5  3.0  8.60         0
# 39         307          108                  2  4.0  3.5  7.70         0
# 149        311          106                  2  3.5  3.0  8.26         1
# 124        301          106                  4  2.5  3.0  8.47         0
# 5          330          115                  5  4.5  3.0  9.34         1
# ..         ...          ...                ...  ...  ...   ...       ...
# 152        321          112                  5  5.0  5.0  9.06         1
# 241        317          103                  2  2.5  2.0  8.15         0
# 186        317          107                  3  3.5  3.0  8.68         1
# 233        304          100                  2  2.5  3.5  8.07         0
# 60         309          100                  2  3.0  3.0  8.10         0
#
# [300 rows x 7 columns]

# %%
print(y_train.shape)
print(y_train)
# Out:
# (300,)
# 9      0.0
# 39     0.0
# 149    0.0
# 124    0.0
# 5      1.0
#       ...
# 152    0.0
# 241    0.0
# 186    0.0
# 233    0.0
# 60     0.0
# Name: Admitted, Length: 300, dtype: float64

# %%
print(x_test.shape)
x_test
# Out:
# (100, 7)
#      GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research
# 15         314          105                  3  3.5  2.5  8.30         0
# 368        298           92                  1  2.0  2.0  7.88         0
# 303        323          107                  3  3.5  3.5  8.55         1
# 82         320          110                  5  5.0  4.5  9.22         1
# 304        313          106                  2  2.5  2.0  8.43         0
# ..         ...          ...                ...  ...  ...   ...       ...
# 387        307          105                  2  2.0  3.5  8.10         0
# 168        293           97                  2  2.0  4.0  7.80         1
# 99         323          113                  3  4.0  4.0  8.88         1
# 100        322          107                  3  3.5  3.5  8.46         1
# 218        324          110                  4  3.0  3.5  8.97         1
#
# [100 rows x 7 columns]

# %%
print(y_test.shape)
y_test
# Out:
# (100,)
# 15     0.0
# 368    0.0
# 303    0.0
# 82     1.0
# 304    0.0
#       ...
# 387    0.0
# 168    0.0
# 99     0.0
# 100    0.0
# 218    0.0
# Name: Admitted, Length: 100, dtype: float64

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(random_state=0,max_depth=3)
clf.fit(x_train,y_train)
y_pred = clf.predict(x_test)
y_pred=y_pred.astype('int64')

# %%
result=pd.DataFrame({"actual":y_test,"predicted":y_pred})
result
# Out:
#      actual  predicted
# 15      0.0          0
# 368     0.0          0
# 303     0.0          0
# 82      1.0          1
# 304     0.0          0
# ..      ...        ...
# 387     0.0          0
# 168     0.0          0
# 99      0.0          0
# 100     0.0          0
# 218     0.0          0
#
# [100 rows x 2 columns]

# %%
from sklearn.metrics import ConfusionMatrixDisplay,accuracy_score,classification_report

# %%
ConfusionMatrixDisplay.from_predictions(y_test,y_pred)

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.97

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.97      0.98        80
#          1.0       0.90      0.95      0.93        20
#
#     accuracy                           0.97       100
#    macro avg       0.95      0.96      0.95       100
# weighted avg       0.97      0.97      0.97       100

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(clf)
# Out:
# [Text(0.4230769230769231, 0.875, 'x[5] <= 9.185\ngini = 0.278\nsamples = 300\nvalue = [250, 50]'),
#  Text(0.15384615384615385, 0.625, 'x[5] <= 9.07\ngini = 0.039\nsamples = 253\nvalue = [248, 5]'),
#  Text(0.07692307692307693, 0.375, 'gini = 0.0\nsamples = 229\nvalue = [229, 0]'),
#  Text(0.23076923076923078, 0.375, 'x[2] <= 4.5\ngini = 0.33\nsamples = 24\nvalue = [19, 5]'),
#  Text(0.15384615384615385, 0.125, 'gini = 0.18\nsamples = 20\nvalue = [18, 2]'),
#  Text(0.3076923076923077, 0.125, 'gini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.6923076923076923, 0.625, 'x[5] <= 9.195\ngini = 0.081\nsamples = 47\nvalue = [2, 45]'),
#  Text(0.5384615384615384, 0.375, 'x[0] <= 332.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.46153846153846156, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6153846153846154, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8461538461538461, 0.375, 'x[0] <= 329.5\ngini = 0.043\nsamples = 45\nvalue = [1, 44]'),
# ...

# %%
plt.figure(figsize=(10,10))
features = ["GRE Score",	"TOEFL Score",	"University Rating",	"SOP",	"LOR",	"CGPA",	"Research"]
plot_tree(clf,fontsize=8,filled=True,feature_names=features,class_names=['NotAdmitted','Admitted'])
# Out:
# [Text(0.4230769230769231, 0.875, 'CGPA <= 9.185\ngini = 0.278\nsamples = 300\nvalue = [250, 50]\nclass = NotAdmitted'),
#  Text(0.15384615384615385, 0.625, 'CGPA <= 9.07\ngini = 0.039\nsamples = 253\nvalue = [248, 5]\nclass = NotAdmitted'),
#  Text(0.07692307692307693, 0.375, 'gini = 0.0\nsamples = 229\nvalue = [229, 0]\nclass = NotAdmitted'),
#  Text(0.23076923076923078, 0.375, 'University Rating <= 4.5\ngini = 0.33\nsamples = 24\nvalue = [19, 5]\nclass = NotAdmitted'),
#  Text(0.15384615384615385, 0.125, 'gini = 0.18\nsamples = 20\nvalue = [18, 2]\nclass = NotAdmitted'),
#  Text(0.3076923076923077, 0.125, 'gini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Admitted'),
#  Text(0.6923076923076923, 0.625, 'CGPA <= 9.195\ngini = 0.081\nsamples = 47\nvalue = [2, 45]\nclass = Admitted'),
#  Text(0.5384615384615384, 0.375, 'GRE Score <= 332.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = NotAdmitted'),
# ...

# %%
dtr = DecisionTreeClassifier(criterion="entropy",random_state=0,max_depth=3)
dtr.fit(x_train,y_train)
y_pred = dtr.predict(x_test)
y_pred=y_pred.astype('int64')

# %%
ConfusionMatrixDisplay.from_predictions(y_test,y_pred)

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.95

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.97      0.97        80
#          1.0       0.89      0.85      0.87        20
#
#     accuracy                           0.95       100
#    macro avg       0.93      0.91      0.92       100
# weighted avg       0.95      0.95      0.95       100

# %%
plt.figure(figsize=(10,10))
plot_tree(dtr,fontsize=8,filled=True,feature_names=features,class_names=['NotAdmitted','Admitted'])
# Out:
# [Text(0.5, 0.875, 'CGPA <= 9.185\nentropy = 0.65\nsamples = 300\nvalue = [250, 50]\nclass = NotAdmitted'),
#  Text(0.2, 0.625, 'CGPA <= 9.07\nentropy = 0.14\nsamples = 253\nvalue = [248, 5]\nclass = NotAdmitted'),
#  Text(0.1, 0.375, 'entropy = 0.0\nsamples = 229\nvalue = [229, 0]\nclass = NotAdmitted'),
#  Text(0.3, 0.375, 'SOP <= 4.25\nentropy = 0.738\nsamples = 24\nvalue = [19, 5]\nclass = NotAdmitted'),
#  Text(0.2, 0.125, 'entropy = 0.0\nsamples = 11\nvalue = [11, 0]\nclass = NotAdmitted'),
#  Text(0.4, 0.125, 'entropy = 0.961\nsamples = 13\nvalue = [8, 5]\nclass = NotAdmitted'),
#  Text(0.8, 0.625, 'GRE Score <= 329.5\nentropy = 0.254\nsamples = 47\nvalue = [2, 45]\nclass = Admitted'),
#  Text(0.7, 0.375, 'GRE Score <= 328.5\nentropy = 0.722\nsamples = 10\nvalue = [2, 8]\nclass = Admitted'),
#  Text(0.6, 0.125, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = Admitted'),
#  Text(0.8, 0.125, 'entropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = NotAdmitted'),
# ...

# %%
import warnings
warnings.filterwarnings("ignore")
new=[[398,116,4,5.0,4.5,9.45,1]]
res=clf.predict(new)
if(res==0):
    print("Not Admitted")
else:
    print("Admitted")
# Out:
# Admitted
